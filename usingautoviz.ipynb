# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./data/Customers.csv')
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# 3         Lawyer                0            2
# 4  Entertainment                2            6

# %%
from autoviz.AutoViz_Class import AutoViz_Class

# %%
AV= AutoViz_Class()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
filename = "./data/Customers.csv"

dft = AV.AutoViz(
    filename
)
# Out:
# Shape of your Data Set loaded: (2000, 8)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     8 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['CustomerID']
# To fix data quality issues automatically, import FixDQ from autoviz...
# <style type="text/css">
# #T_4f67e_row0_col0, #T_4f67e_row0_col5, #T_4f67e_row1_col0, #T_4f67e_row1_col5, #T_4f67e_row2_col0, #T_4f67e_row2_col5, #T_4f67e_row3_col0, #T_4f67e_row3_col5, #T_4f67e_row4_col0, #T_4f67e_row4_col5, #T_4f67e_row5_col0, #T_4f67e_row5_col5, #T_4f67e_row6_col0, #T_4f67e_row6_col5, #T_4f67e_row7_col0, #T_4f67e_row7_col5 {
#   font-family: Segoe UI;
# }
# #T_4f67e_row0_col1, #T_4f67e_row1_col1, #T_4f67e_row1_col2, #T_4f67e_row2_col1, #T_4f67e_row2_col3, #T_4f67e_row2_col4, #T_4f67e_row3_col1, #T_4f67e_row3_col3, #T_4f67e_row4_col1, #T_4f67e_row4_col3, #T_4f67e_row4_col4, #T_4f67e_row5_col2, #T_4f67e_row6_col1, #T_4f67e_row6_col2, #T_4f67e_row6_col3, #T_4f67e_row6_col4, #T_4f67e_row7_col1, #T_4f67e_row7_col2, #T_4f67e_row7_col4 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_4f67e_row0_col2, #T_4f67e_row0_col3, #T_4f67e_row3_col4, #T_4f67e_row5_col1, #T_4f67e_row7_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_4f67e_row0_col4 {
#   background-color: #fff4ee;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_4f67e_row1_col3, #T_4f67e_row1_col4, #T_4f67e_row5_col3, #T_4f67e_row5_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_4f67e_row2_col2, #T_4f67e_row4_col2 {
#   background-color: #ffede5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_4f67e_row3_col2 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_4f67e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f67e_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_4f67e_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_4f67e_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_4f67e_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_4f67e_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_4f67e_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f67e_level0_row0" class="row_heading level0 row0" >CustomerID</th>
#       <td id="T_4f67e_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_4f67e_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_4f67e_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_4f67e_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_4f67e_row0_col4" class="data row0 col4" >2000.000000</td>
#       <td id="T_4f67e_row0_col5" class="data row0 col5" >Possible ID colum: drop before modeling process.</td>
#     </tr>
#     <tr>
#       <th id="T_4f67e_level0_row1" class="row_heading level0 row1" >Gender</th>
#       <td id="T_4f67e_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_4f67e_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_4f67e_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_4f67e_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_4f67e_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_4f67e_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_4f67e_level0_row2" class="row_heading level0 row2" >Age</th>
#       <td id="T_4f67e_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_4f67e_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_4f67e_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_4f67e_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_4f67e_row2_col4" class="data row2 col4" >99.000000</td>
#       <td id="T_4f67e_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_4f67e_level0_row3" class="row_heading level0 row3" >Annual Income ($)</th>
#       <td id="T_4f67e_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_4f67e_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_4f67e_row3_col2" class="data row3 col2" >89</td>
#       <td id="T_4f67e_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_4f67e_row3_col4" class="data row3 col4" >189974.000000</td>
#       <td id="T_4f67e_row3_col5" class="data row3 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_4f67e_level0_row4" class="row_heading level0 row4" >Spending Score (1-100)</th>
#       <td id="T_4f67e_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_4f67e_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_4f67e_row4_col2" class="data row4 col2" >5</td>
#       <td id="T_4f67e_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_4f67e_row4_col4" class="data row4 col4" >100.000000</td>
#       <td id="T_4f67e_row4_col5" class="data row4 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_4f67e_level0_row5" class="row_heading level0 row5" >Profession</th>
#       <td id="T_4f67e_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_4f67e_row5_col1" class="data row5 col1" >1.750000</td>
#       <td id="T_4f67e_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_4f67e_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_4f67e_row5_col4" class="data row5 col4" >nan</td>
#       <td id="T_4f67e_row5_col5" class="data row5 col5" >35 missing values. Impute them with mean, median, mode, or a constant value such as 123., Mixed dtypes: has 2 different data types:  object, float,</td>
#     </tr>
#     <tr>
#       <th id="T_4f67e_level0_row6" class="row_heading level0 row6" >Work Experience</th>
#       <td id="T_4f67e_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_4f67e_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_4f67e_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_4f67e_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_4f67e_row6_col4" class="data row6 col4" >17.000000</td>
#       <td id="T_4f67e_row6_col5" class="data row6 col5" >has 5 outliers greater than upper bound (16.00) or lower than lower bound(-8.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_4f67e_level0_row7" class="row_heading level0 row7" >Family Size</th>
#       <td id="T_4f67e_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_4f67e_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_4f67e_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_4f67e_row7_col3" class="data row7 col3" >1.000000</td>
#       <td id="T_4f67e_row7_col4" class="data row7 col4" >9.000000</td>
#       <td id="T_4f67e_row7_col5" class="data row7 col5" >No issue</td>
#     </tr>
#   </tbody>
# </table>
# Number of All Scatter Plots = 15
# All Plots done
# Time to run AutoViz = 5 seconds
#
#  Done Visualizing!!
